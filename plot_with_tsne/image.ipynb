# %%
from PIL import Image
import numpy as np

# %%
im = Image.open("image2/eta/output/eta_original_image_172.jpg_125accde-1cc6-461d-bccc-a625f414fe2b.jpg")

# %%
im2=im.resize((300,300),Image.ANTIALIAS)
im2
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x203D4665D08>
